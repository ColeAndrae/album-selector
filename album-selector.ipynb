# %%
import pandas as pd

music_data = pd.read_csv("music.csv")

YEAR = '1997'

music_data[music_data['release_date'].str.startswith(YEAR)]
# Out:
#       Unnamed: 0  position               release_name  \
# 0              1         1                OK Computer
# 65            66        66                  Homogenic
# 77            78        78                      F♯A♯∞
# 107          108       108                Either / Or
# 220          221       221  The Lonesome Crowded West
# ...          ...       ...                        ...
# 4606        4607      4607                Cherry Peel
# 4738        4739      4739      Uptown Saturday Night
# 4772        4773      4773                Brown Album
# 4834        4835      4835      The End of Evangelion
# 4949        4950      4950           Mi media naranja
#
#                       artist_name release_date release_type  \
# 0                       Radiohead   1997-06-16        album
# 65                          Björk   1997-09-22        album
# 77    Godspeed You Black Emperor!   1997-08-14        album
# 107                 Elliott Smith   1997-02-25        album
# ...
